# %%
import pdfplumber
import pandas as pd

# %%
pdf = pdfplumber.open("cyhy-GSA-2019-11-23-https-report.pdf")

# %%
websites = []

for page in pdf.pages:
    table = page.extract_table()
    
    if table is not None:
        for row in table:
            websites.append(row[0])

# %%
websites
# Out:
# ['18f.gov',
#  'accessibility.gov',
#  'acquisition.gov',
#  'afadvantage.gov',
#  'businessusa.gov',
#  'buyaccessible.gov',
#  'buyamerican.gov',
#  'cao.gov',
#  'cbca.gov',
#  'cfda.gov',
#  'cfo.gov',
#  'challenge.gov',
#  'challenges.gov',
#  'cio.gov',
#  'citizenscience.gov',
#  'cloud.gov',
#  'code.gov',
#  'api.code.gov',
#  'developers.code.gov',
#  'staging.code.gov',
#  'computersforlearning.gov',
#  'connect.gov',
#  'consumeraction.gov',
#  'contractdirectory.gov',
#  'cpars.gov',
#  'data.gov',
#  'digital.gov',
#  'digitaldashboard.gov',
#  'digitalgov.gov',
#  'dotgov.gov',
#  'ecpic.gov',
#  'esrs.gov',
#  'everykidinapark.gov',
#  'faca.gov',
#  'facadatabase.gov',
#  'fai.gov',
#  'content.fai.gov',
#  'ldap.fai.gov',
#  'fapiis.gov',
#  'fbf.gov',
#  'fbo.gov',
#  'smtp.fbo.gov',
#  'fdms.gov',
#  'fedbizopps.gov NotLive',
#  'fedidcard.gov',
#  'fedinfo.gov NotLive',
#  'fedramp.gov',
#  'demo.fedramp.gov',
#  'marketplace.fedramp.gov',
#  'tailored.fedramp.gov',
#  'fedrooms.gov',
#  'firstgov.gov',
#  'fmi.gov',
#  'forms.gov',
#  'fpc.gov',
#  'fpds.gov',
#  'beta.fpds.gov',
#  'fpisc.gov NotLive',
#  'calendar.fpisc.gov',
#  'docs.fpisc.gov',
#  'email.fpisc.gov',
#  'groups.fpisc.gov',
#  'fpki-lab.gov NotLive',
#  'http.apl-test.cite.fpki-lab.gov',
#  'http.cite.fpki-lab.gov',
#  'fpki.gov NotLive',
#  'http.fpki.gov',
#  'omon.fpki.gov',
#  'omon2.fpki.gov',
#  'frpg.gov',
#  'fsd.gov',
#  'fsrs.gov',
#  'gobiernousa.gov',
#  'apps.gobiernousa.gov',
#  'blog.gobiernousa.gov',
#  'conectate.gobiernousa.gov',
#  'm.gobiernousa.gov',
#  'respuestas.gobiernousa.gov',
#  'govsales.gov',
#  'gsa.gov',
#  '10x.gsa.gov',
#  '18f.gsa.gov',
#  'aaap.gsa.gov',
#  'aaapextsb.pbs.gsa.gov',
#  'aacinquiry.fas.gsa.gov',
#  'aas.gsa.gov',
#  'ack.usaccess.gsa.gov',
#  'acquisition-uat.gsa.gov',
#  'advantage.gsa.gov',
#  'agencypricer.wits3.gsa.gov',
#  'aldp.gsa.gov',
#  'amp.fas.gsa.gov',
#  'anywhere.gsa.gov',
#  'api.gsa.gov',
#  'apps.fas.gsa.gov',
#  'apps.ocfo.gsa.gov',
#  'arm.fas.gsa.gov',
#  'asap.gsa.gov',
#  'ask.gsa.gov',
#  'aspdotnetstorefront.webshops.fas.gsa.gov',
#  'aspdotnetstorefront.webshopt.fas.gsa.gov',
#  'autoauctions.gsa.gov',
#  'autoauctionsb.fas.gsa.gov',
#  'autochoice.fas.gsa.gov',
#  'autochoice.gsa.gov',
#  'autovendor.fas.gsa.gov',
#  'benchmarks.gsa.gov',
#  'cabotp.gsa.gov',
#  'calc.gsa.gov',
#  'calendar.gsa.gov',
#  'callcenter.fas.gsa.gov',
#  'carbonfootprint.gsa.gov',
#  'cars.fas.gsa.gov',
#  'cfo.fmis.gsa.gov',
#  'cfo.gsa.gov',
#  'cmls.gsa.gov',
#  'cmp.gsa.gov',
#  'coe.gsa.gov',
#  'cognos.pbs.gsa.gov',
#  'concur.gsa.gov',
#  'conexus-cert.gsa.gov',
#  'conexus.gsa.gov',
#  'connect.gsa.gov',
#  'connectionsii-clinchecker.fas.gsa.gov',
#  'content.gsaadvantage.fas.gsa.gov',
#  'cops.fas.gsa.gov',
#  'corporateapps.gsa.gov',
#  'cpsearch.fas.gsa.gov',
#  'css-staging.d2d.gsa.gov',
#  'css.d2d.gsa.gov',
#  'd2d.gsa.gov',
#  'dashboard.ocfo.gsa.gov',
#  'debits.fas.gsa.gov',
#  'debitsb.fas.gsa.gov',
#  'demo.10x.gsa.gov',
#  'dhsadvantage.gsa.gov',
#  'discovery.gsa.gov',
#  'disposal.gsa.gov',
#  'drivethru.gsa.gov',
#  'drivethrub.gsa.gov',
#  'ebuy-test.fas.gsa.gov',
#  'ebuy.gsa.gov',
#  'ebuyconnect-test.fas.gsa.gov',
#  'ebuyconnect.fas.gsa.gov',
#  'ectran.fas.gsa.gov',
#  'egov.gsa.gov',
#  'elibrary-test.fas.gsa.gov',
#  'email.gsa.gov',
#  'email2.gsa.gov',
#  'emorris.fasbilling.gsa.gov',
#  'emorriscert.fasbilling.gsa.gov',
#  'eoc.gsa.gov',
#  'eoffer-test.fas.gsa.gov',
#  'eoffer.gsa.gov',
#  'epay.fas.gsa.gov',
#  'epayb.fas.gsa.gov',
#  'epm.pbs.gsa.gov',
#  'etools.fas.gsa.gov',
#  'etsvendorsales.gsa.gov',
#  'expressplatform.aas.gsa.gov',
#  'extaaapgis.gsa.gov',
#  'extcws.fas.gsa.gov',
#  'extgsagis.gsa.gov',
#  'extportal.pbs.gsa.gov',
#  'fas.connect.gsa.gov',
#  'febatl.platform.gsa.gov',
#  'fedmz.gsa.gov',
#  'fedpay.gsa.gov',
#  'fedpay.gss.gsa.gov',
#  'fedsim.gsa.gov',
#  'fedspecs.gsa.gov',
#  'feedback.gsa.gov',
#  'ffms.fas.gsa.gov',
#  'ffmsb.fas.gsa.gov',
#  'finance.gsa.gov',
#  'finance.ocfo.gsa.gov',
#  'finance3.gsa.gov',
#  'fleet.fas.gsa.gov',
#  'fleet.gsa.gov',
#  'fleetb.gsa.gov',
#  'fleeteur.fas.gsa.gov',
#  'fleeteurb.fas.gsa.gov',
#  'fleetsso.gsa.gov',
#  'fms.fas.gsa.gov',
#  'fms1-meet.gsa.gov',
#  'fms2-meet.gsa.gov',
#  'fms3-meet.gsa.gov',
#  'fms4-meet.gsa.gov',
#  'fms5-meet.gsa.gov',
#  'fms6-meet.gsa.gov',
#  'fmswseb.fas.gsa.gov',
#  'fmswsec.fas.gsa.gov',
#  'fmvrs.fas.gsa.gov',
#  'fmvrsb.fas.gsa.gov',
#  'forcegis.gsa.gov',
#  'fpkia.gsa.gov',
#  'frppmap.gsa.gov',
#  'ftp.gsa.gov',
#  'globalsupply.gsa.gov',
#  'govsalesupload.fas.gsa.gov',
#  'govsalesuploadb.fas.gsa.gov',
#  'gsa-apps.gsa.gov',
#  'gsaadvantage-cors.fas.gsa.gov',
#  'gsaadvantage-test.fas.gsa.gov',
#  'gsaadvantage-test2.fas.gsa.gov',
#  'gsaadvantage.gsa.gov',
#  'gsaauctionsextapp.gsa.gov',
#  'gsabin.fas.gsa.gov',
#  'gsablogs.gsa.gov',
#  'gsac0.fas.gsa.gov',
#  'gsacin.fas.gsa.gov',
#  'gsadvantage.gsa.gov',
#  'gsaelibrary.gsa.gov',
#  'gsafcu.gsa.gov',
#  'gsafinearts.pbs.gsa.gov',
#  'gsafleet2go.fas.gsa.gov',
#  'gsafleet2gob.fas.gsa.gov',
#  'gsagis.pbs.gsa.gov',
#  'gsaglobalsupply.gsa.gov',
#  'gsaolu.gsa.gov',
#  'gsasolutionssecure.gsa.gov',
#  'gsaupload.fas.gsa.gov',
#  'gsaxcesspractice.fas.gsa.gov',
#  'gsbca.gsa.gov',
#  'gsbca2.gsa.gov',
#  'hallways-staging.cap.gsa.gov',
#  'hallways.cap.gsa.gov',
#  'hydra.gsa.gov',
#  'innovation.gsa.gov',
#  'insite-cmp.gsa.gov',
#  'insite.gsa.gov',
#  'intaaapgis.gsa.gov',
#  'interact.gsa.gov',
#  'iolp.gsa.gov',
#  'issuance.usaccess.gsa.gov',
#  'ithelp.gsa.gov',
#  'itjobs.open.gsa.gov',
#  'join.tts.gsa.gov',
#  'jss.gsa.gov',
#  'labs.gsa.gov',
#  'listserv.gsa.gov',
#  'lmt.pbs.gsa.gov',
#  'lop.gsa.gov',
#  'm.gsa.gov',
#  'mcm-admin.fas.gsa.gov',
#  'mcm.fas.gsa.gov',
#  'meet-sso.gsa.gov',
#  'meet.gsa.gov',
#  'meetcqauth1.gsa.gov',
#  'meetcqpub1.gsa.gov',
#  'mentor-protege.gsa.gov',
#  'mobile.anywhere.gsa.gov',
#  'moveit.gsa.gov',
#  'mysales.fas.gsa.gov',
#  'mysalesb.fas.gsa.gov',
#  'mysmartplans.gsa.gov',
#  'myview-dev.gsa.gov',
#  'myview-rd.gsa.gov',
#  'myview-test.gsa.gov',
#  'navigator.gsa.gov',
#  'ncportal.fas.gsa.gov',
#  'ncportals.fas.gsa.gov',
#  'ncportalt.fas.gsa.gov',
#  'ncr-vpn.gsa.gov',
#  'ncr.anywhere.gsa.gov',
#  'ncreportings.fas.gsa.gov',
#  'ncrrecycles.gsa.gov',
#  'ncsc-reports.gsa.gov',
#  'nonpiv-issuance.usaccess.gsa.gov',
#  'nsp-ocsit.net.helix.gsa.gov',
#  'oasispet.gsa.gov',
#  'odc.d2d.gsa.gov',
#  'oes.gsa.gov',
#  'oig.gsa.gov',
#  'open.gsa.gov',
#  'orders-vp-staging.fas.gsa.gov',
#  'orders-vp.fas.gsa.gov',
#  'origin-www.gsa.gov',
#  'ors.fas.gsa.gov',
#  'p3.cap.gsa.gov',
#  'par.gsa.gov',
#  'pbs-billing.gsa.gov',
#  'pegasys.gsa.gov',
#  'phdc-pub.gsa.gov',
#  'pif.gsa.gov',
#  'plc.platform.gsa.gov',
#  'poportal.gsa.gov',
#  'portal.fas.gsa.gov',
#  'portal.usaccess.gsa.gov',
#  'preview-insite.gsa.gov',
#  'preview.gsa.gov',
#  'propertydisposal.gsa.gov',
#  'publiccourts.gsa.gov',
#  'publicpricer.wits3.gsa.gov',
#  'pueblo.gsa.gov',
#  'r05-voipedge.gsa.gov',
#  'r06.anywhere.gsa.gov',
#  'r2.gsa.gov',
#  'r4.gsa.gov',
#  'r6-vpn.gsa.gov',
#  'r7-vpn.gsa.gov',
#  'rap.usaccess.gsa.gov',
#  'rc.gsa.gov',
#  'region9.gsa.gov',
#  'ret.gsa.gov',
#  'reverseauctions.gsa.gov',
#  'reverseauctionsdemo.gsa.gov',
#  'roadsviewb.fas.gsa.gov',
#  'sasyec.fas.gsa.gov',
#  'scopereview.gsa.gov',
#  'search.gsa.gov',
#  'secureauth.dev.gsa.gov',
#  'secureauth.gsa.gov',
#  'servicedesk.gsa.gov',
#  'services.usaccess.gsa.gov',
#  'slc.gsa.gov',
#  'smartpay.gsa.gov',
#  'soa-ext.fas.gsa.gov',
#  'srp.fas.gsa.gov',
#  'ssq.gsa.gov',
#  'staging-odc.d2d.gsa.gov',
#  'staging-tableau.d2d.gsa.gov',
#  'staging.d2d.gsa.gov',
#  'str.fas.gsa.gov',
#  'str.gsa.gov',
#  'sws.gsa.gov',
#  'tableau.d2d.gsa.gov',
#  'tarpseb-dev.fas.gsa.gov',
#  'tarpsec.fas.gsa.gov',
#  'tech.gsa.gov',
#  'test-iis.gss.gsa.gov',
#  'test-iis.ocfo.gsa.gov',
#  'topsbill.ftsbilling.gsa.gov',
#  'topsbillcert.ftsbilling.gsa.gov',
#  'topsorder.ftsbilling.gsa.gov',
#  'topsordercert.ftsbilling.gsa.gov',
#  'tpi.moveit.gsa.gov',
#  'train-tpi.moveit.gsa.gov',
#  'training.smartpay.gsa.gov',
#  'tscportal.fas.gsa.gov',
#  'tss-staging.d2d.gsa.gov',
#  'tss.d2d.gsa.gov',
#  'uat-origin-www.gsa.gov',
#  'usaccess-alp.gsa.gov',
#  'usagov.platform.gsa.gov',
#  'usdaadvantage.gsa.gov',
#  'usmcservmart.gsa.gov',
#  'ussm.gsa.gov',
#  'vaadvantage.gsa.gov',
#  'vasalesportal.gsa.gov',
#  'vcss.gsa.gov',
#  'vcss.ocfo.gsa.gov',
#  'vec.gsa.gov',
#  'vehicledispatch.fas.gsa.gov',
#  'vehiclestd.fas.gsa.gov',
#  'vehiclestdb.fas.gsa.gov',
#  'vpn.gsa.gov',
#  'vpndev.gsa.gov',
#  'vpntest.gsa.gov',
#  'vpntest2.gsa.gov',
#  'vsc.gsa.gov',
#  'vscftp.gsa.gov',
#  'was.itss.gsa.gov',
#  'web.itss.gsa.gov',
#  'webservices.fas.gsa.gov',
#  'webservicesb.fas.gsa.gov',
#  'webshop.gsa.gov',
#  'gsaadvantage.gov',
#  'gsaauctions.gov',
#  'gsaig.gov',
#  'lft.gsaig.gov',
#  'ln-traveler-e02.gsaig.gov',
#  'ln-traveler-w01.gsaig.gov',
#  'public-meeting.gsaig.gov',
#  'support.gsaig.gov',
#  'vpn.gsaig.gov',
#  'gsatest1.gov NotLive',
#  'gsatest2.gov NotLive',
#  'gsaxcess.gov',
#  'howto.gov',
#  'identitysandbox.gov NotLive',
#  'app.brody.identitysandbox.gov',
#  'brody.identitysandbox.gov',
#  'ci.identitysandbox.gov',
#  'crissupb.identitysandbox.gov',
#  'dashboard.brody.identitysandbox.gov',
#  'dev.identitysandbox.gov',
#  'idp.brody.identitysandbox.gov',
#  'idp.ci.identitysandbox.gov',
#  'idp.crissupb.identitysandbox.gov',
#  'idp.dev.identitysandbox.gov',
#  'idp.int.identitysandbox.gov',
#  'idp.jjg.identitysandbox.gov',
#  'idp.qa.identitysandbox.gov',
#  'int.identitysandbox.gov',
#  'jjg.identitysandbox.gov',
#  'pivcac.crissupb.identitysandbox.gov',
#  'pivcac.int.identitysandbox.gov',
#  'pivcac.jjg.identitysandbox.gov',
#  'qa.identitysandbox.gov',
#  'sp-oidc-sinatra.brody.identitysandbox.gov',
#  'sp-rails.brody.identitysandbox.gov',
#  'sp-sinatra.brody.identitysandbox.gov',
#  'sp.brody.identitysandbox.gov',
#  'sp.ci.identitysandbox.gov',
#  'sp.crissupb.identitysandbox.gov',
#  'sp.dev.identitysandbox.gov',
#  'sp.int.identitysandbox.gov',
#  'sp.jjg.identitysandbox.gov',
#  'sp.qa.identitysandbox.gov',
#  'idmanagement.gov',
#  'info.gov',
#  'innovation.gov',
#  'itdashboard.gov',
#  'kids.gov',
#  'login.gov',
#  'nic.gov',
#  'pbrb.gov NotLive',
#  'performance.gov',
#  'cms.permits.performance.gov',
#  'cms7.permits.performance.gov',
#  'data.permits.performance.gov',
#  'obamaadministration.archives.performance.gov',
#  'permits.performance.gov',
#  'staging.performance.gov',
#  'pic.gov',
#  'demo.pic.gov',
#  'pif.gov',
#  'apply.pif.gov',
#  'fellows-in-innovation.pif.gov',
#  'paygap.pif.gov',
#  'proposal.pif.gov',
#  'review.pif.gov',
#  'pki-lab.gov NotLive',
#  'pki.gov NotLive',
#  'plainlanguage.gov',
#  'demo.plainlanguage.gov',
#  'ppirs.gov',
#  'alpha.ppirs.gov',
#  'beta.ppirs.gov',
#  'fapiis.ppirs.gov',
#  'presidentialinnovationfellows.gov',
#  'ptt.gov NotLive',
#  'realestatesales.gov',
#  'realpropertyprofile.gov',
#  'reginfo.gov',
#  'regulations.gov',
#  'reporting.gov',
#  'rocis.gov',
#  'sam.gov',
#  'alpha.sam.gov',
#  'alphareporting.sam.gov',
#  'api-alpha.sam.gov',
#  'api.sam.gov',
#  'beta.sam.gov',
#  'designsystem.sam.gov',
#  'fardatacollection.sam.gov',
#  'fbohome.sam.gov',
#  'gw.sam.gov',
#  'open.sam.gov',
#  'reporting.sam.gov',
#  'wdolhome.sam.gov',
#  'sandbox.gov NotLive',
#  'sbst.gov',
#  'search.gov',
#  'section508.gov',
#  'sftool.gov',
#  'us.gov',
#  'usa.gov',
#  '1.usa.gov',
#  'analytics.usa.gov',
#  'answers.usa.gov',
#  'api.usa.gov',
#  'apps.usa.gov',
#  'asis.search.usa.gov',
#  'blog.usa.gov',
#  'buscador.usa.gov',
#  'business.usa.gov',
#  'cm-jira.usa.gov',
#  'components.standards.usa.gov',
#  'connect.usa.gov',
#  'consumercomplaintletter.usa.gov',
#  'demo1.search.usa.gov',
#  'demo1.staging.infr.search.usa.gov',
#  'demo2.search.usa.gov',
#  'demo2.staging.infr.search.usa.gov',
#  'demo3.search.usa.gov',
#  'demo3.staging.infr.search.usa.gov',
#  'epa-notice.usa.gov',
#  'feedback-staging.usa.gov',
#  'feedback.usa.gov',
#  'go.usa.gov',
#  'gobierno.usa.gov',
#  'i14y.search.usa.gov',
#  'i14y.usa.gov',
#  'kibana.demo1.search.usa.gov',
#  'kibana.demo2.search.usa.gov',
#  'kibana.demo3.search.usa.gov',
#  'kibana.search.usa.gov',
#  'kibana5.demo1.search.usa.gov',
#  'kibana5.demo2.search.usa.gov',
#  'kibana5.demo3.search.usa.gov',
#  'kids.usa.gov',
#  'labs.usa.gov',
#  'm.usa.gov',
#  'my.usa.gov',
#  'notice.usa.gov',
#  'notifications.usa.gov',
#  'open-staging.usa.gov',
#  'open.usa.gov',
#  'participation.usa.gov',
#  'promotions.usa.gov',
#  'proxylb.us-east-1.infr.search.usa.gov',
#  'publications.usa.gov',
#  'registry.usa.gov',
#  'resque.demo1.search.usa.gov',
#  'resque.demo2.search.usa.gov',
#  'resque.demo3.search.usa.gov',
#  'resque.search.usa.gov',
#  'search.usa.gov',
#  'standards.usa.gov',
#  'tell-us.usa.gov',
#  'tellus.usa.gov',
#  'vote.usa.gov',
#  'usagov.gov',
#  'ussm.gov',
#  'vote.gov',
#  'wdol.gov']

# %%
df = pd.DataFrame({'Website_Name': websites})
df
# Out:
#           Website_Name
# 0              18f.gov
# 1    accessibility.gov
# 2      acquisition.gov
# 3      afadvantage.gov
# 4      businessusa.gov
# ..                 ...
# 523       vote.usa.gov
# 524         usagov.gov
# 525           ussm.gov
# 526           vote.gov
# 527           wdol.gov
#
# [528 rows x 1 columns]

# %%
df.to_csv('websites.csv')
