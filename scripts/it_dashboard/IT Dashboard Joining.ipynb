# %%
import pandas as pd

# %% [markdown]
# # Business Case

# %%
business_case = pd.read_csv("it_dashboard_business_case.csv")

# %%
business_case.head()
# Out:
#   Unique Investment Identifier  Business Case ID Investment Type  \
# 0                023-000000058              1726   01 - Major IT
# 1                023-000000053              1611   01 - Major IT
# 2                023-000000088              1937   01 - Major IT
# 3                023-000001700              1734   01 - Major IT
# 4                023-000004270              1213   01 - Major IT
#
#   Infrastructure Management Category  Agency Code  \
# 0                01 - Not Applicable           23
# 1                01 - Not Applicable           23
# 2                01 - Not Applicable           23
# 3                01 - Not Applicable           23
# 4                01 - Not Applicable           23
#
#                        Agency Name  Bureau Code  \
# 0  General Services Administration           10
# 1  General Services Administration           10
# 2  General Services Administration           30
# 3  General Services Administration           10
# ...

# %%
business_case['Bureau Name'].unique()
# Out:
# array(['Supply and Technology Activities', 'General Activities',
#        'Real Property Activities'], dtype=object)

# %%
sorted(business_case.columns)
# Out:
# ['Agency Code',
#  'Agency Name',
#  'Agency Strategic Objectives / Agency Priority Goals',
#  'Analysis Conclusion',
#  'Budget Year',
#  'Bureau Code',
#  'Bureau Name',
#  'Business Case ID',
#  'CIO Evaluation Color',
#  'CIO Evaluation Comments',
#  'Consecutive Months with Red CIO Eval',
#  'Data Freshness',
#  'Date Investment First Submitted',
#  'Date of Last Baseline',
#  'Date of Last Change to Activities',
#  'Date of Last Change to CIO Evaluation',
#  'Date of Last Change to Performance Metrics',
#  'Date of Last Investment Detail Update',
#  'Date of Last Update to Activities',
#  'Date of Last Update to CIO Evaluation',
#  'Date of Last Update to Performance Metric Actuals',
#  'Evaluation (by Agency CIO)',
#  'Explanation of Change to PY or CY Funding',
#  'Funding BY ($ M)',
#  'Funding CY ($ M)',
#  'Funding PY ($ M)',
#  'Funding PY1 and Prior ($ M)',
#  'Infrastructure Management Category',
#  'Investment Auto Submission Date',
#  'Investment End Year',
# ...

# %%
business_case['Bureau Name'].unique()
# Out:
# array(['Supply and Technology Activities', 'General Activities',
#        'Real Property Activities'], dtype=object)

# %%
business_case = pd.read_csv("it_dashboard_business_case.csv",
                            usecols=['Unique Investment Identifier', 'CIO Evaluation Comments', 'Investment Start Year', 'Investment End Year', 'PM Name'])

# %%
business_case = business_case.rename(columns={"Unique Investment Identifier": "Unique_Investment_Identifier",
                                              "CIO Evaluation Comments": "Comments",
                                              "Investment Start Year": "Investment_Start_Year",
                                              "Investment End Year": "Investment_End_Year",
                                              "PM Name": "Investment_Manager_Name"}).set_index('Unique_Investment_Identifier')

# %%
business_case.head()
# Out:
#                              Investment_Manager_Name  Investment_Start_Year  \
# Unique_Investment_Identifier
# 023-000000058                           Matthew Ryan                   2017
# 023-000000053                            Brad Powers                   2014
# 023-000000088                          William Wales                   2019
# 023-000001700                        Darlene K. Gore                   2004
# 023-000004270                        Shanae Murraine                   2012
#
#                               Investment_End_Year  \
# Unique_Investment_Identifier
# 023-000000058                                2030
# 023-000000053                                2050
# 023-000000088                                2020
# 023-000001700                                2020
# 023-000004270                                2027
#
#                                                                        Comments
# Unique_Investment_Identifier
# ...

# %%
business_case.dtypes
# Out:
# Investment_Manager_Name    object
# Investment_Start_Year       int64
# Investment_End_Year         int64
# Comments                   object
# dtype: object

# %% [markdown]
# # Portfolio

# %%
portfolio = pd.read_csv("it_dashboard_it_portfolio.csv")

# %%
portfolio.head()
# Out:
#    Agency Code                      Agency Name   Previous UII  \
# 0           23  General Services Administration  023-999993200
# 1           23  General Services Administration  023-999990060
# 2           23  General Services Administration  023-999990080
# 3           23  General Services Administration  023-999991100
# 4           23  General Services Administration  023-999993100
#
#   Unique Investment Identifier         Shared Services Category  \
# 0                023-999993200     24 - E-Gov & LoB initiatives
# 1                023-999990060     24 - E-Gov & LoB initiatives
# 2                023-999990080  48 - Multi-agency collaboration
# 3                023-999991100     24 - E-Gov & LoB initiatives
# 4                023-999993100     24 - E-Gov & LoB initiatives
#
#                     Shared Services Identifier  \
# 0  3200 - Budget Formulation and Execution LoB
# 1                          0060 - E-Rulemaking
# 2            0080 - Multi-agency collaboration
# ...

# %%
portfolio['Derived Status'].unique()
# Out:
# array(['No change in status', 'New', 'Eliminated by funding',
#        'Eliminated by omission'], dtype=object)

# %%
portfolio['Part Of IT Portfolio'].unique()
# Out:
# array(['02 - Administrative Services and Support Systems',
#        '01 - Mission Delivery',
#        '03 - IT Infrastructure, IT Security, and IT Management'],
#       dtype=object)

# %%
portfolio['Bureau Name'].unique()
# Out:
# array(['General Activities', 'Supply and Technology Activities',
#        'Real Property Activities'], dtype=object)

# %%
sorted(portfolio.columns)
# Out:
# ['Agency Code',
#  'Agency Name',
#  'Budget Year',
#  'Bureau Code',
#  'Bureau Name',
#  'Cloud Computing Alternatives Evaluation',
#  'DME BY Agency Funding ($ M)',
#  'DME BY Budget Authority Agency Funding ($ M)',
#  'DME BY Contributions ($ M)',
#  'DME CY Agency Funding ($ M)',
#  'DME CY Contributions ($ M)',
#  'DME PY Agency Funding ($ M)',
#  'DME PY Contributions ($ M)',
#  'Derived Status',
#  'FEA BRM Services - Primary service area',
#  'IT Infrastructure and Management Type',
#  'Investment Description',
#  'Investment Title',
#  'LOB Title',
#  'Mission Delivery and Management Support Area',
#  'Mission Support Investment Category',
#  'National Security Systems Identifier',
#  'O&M BY Agency Funding ($ M)',
#  'O&M BY Budget Authority Agency Funding ($ M)',
#  'O&M BY Contributions ($ M)',
#  'O&M CY Agency Funding ($ M)',
#  'O&M CY Contributions ($ M)',
#  'O&M PY Agency Funding ($ M)',
#  'O&M PY Contributions ($ M)',
#  'Part Of IT Portfolio',
# ...

# %%
portfolio = pd.read_csv("it_dashboard_it_portfolio.csv",
                        usecols=['Unique Investment Identifier', 'Budget Year', 'Investment Title', 'Investment Description', 'Cloud Computing Alternatives Evaluation', 'Derived Status', 'Type of Investment', 'Part Of IT Portfolio', 'FEA BRM Services - Primary service area', 'Updated Date',
                                 'O&M BY Agency Funding ($ M)',
                                 'O&M BY Budget Authority Agency Funding ($ M)',
                                 'O&M BY Contributions ($ M)',
                                 'O&M CY Agency Funding ($ M)',
                                 'O&M CY Contributions ($ M)',
                                 'O&M PY Agency Funding ($ M)',
                                 'O&M PY Contributions ($ M)',
                                 'DME BY Agency Funding ($ M)',
                                 'DME BY Budget Authority Agency Funding ($ M)',
                                 'DME BY Contributions ($ M)',
                                 'DME CY Agency Funding ($ M)',
                                 'DME CY Contributions ($ M)',
                                 'DME PY Agency Funding ($ M)',
                                 'DME PY Contributions ($ M)',
                                 'Total IT Spending FY2019 (PY) ($ M)',
                                 'Total IT Spending FY2020 (CY) ($ M)',
                                 'Total IT Spending FY2021 (BY) ($ M)', ])

# %%
portfolio = portfolio.rename(columns={"Unique Investment Identifier": "Unique_Investment_Identifier",
                                      "Budget Year": "Budget_Year",
                                      "Investment Title": "Investment_Name",
                                      "Investment Description": "Description",
                                      "Cloud Computing Alternatives Evaluation": "Cloud_Computing_Alternatives_Evaluation",
                                      "Derived Status": "Investment_Status_Name",
                                      "Type of Investment": "Investment_Type",
                                      "Part Of IT Portfolio": "IT_Portfolio",
                                      "FEA BRM Services - Primary service area": "primary_service_area",
                                      "Updated Date": "Updated_Date"}).set_index('Unique_Investment_Identifier')

# %%
portfolio.head()
# Out:
#                                                                   IT_Portfolio  \
# Unique_Investment_Identifier
# 023-999993200                 02 - Administrative Services and Support Systems
# 023-999990060                 02 - Administrative Services and Support Systems
# 023-999990080                                            01 - Mission Delivery
# 023-999991100                 02 - Administrative Services and Support Systems
# 023-999993100                 02 - Administrative Services and Support Systems
#
#                                     Investment_Type  \
# Unique_Investment_Identifier
# 023-999993200                 04 - Funding Transfer
# 023-999990060                 04 - Funding Transfer
# 023-999990080                     02 - Non-major IT
# 023-999991100                 04 - Funding Transfer
# 023-999993100                 04 - Funding Transfer
#
#                                                   Investment_Name  \
# Unique_Investment_Identifier
# ...

# %%
portfolio.dtypes
# Out:
# IT_Portfolio                                     object
# Investment_Type                                  object
# Investment_Name                                  object
# Description                                      object
# primary_service_area                             object
# Total IT Spending FY2019 (PY) ($ M)             float64
# Total IT Spending FY2020 (CY) ($ M)             float64
# Total IT Spending FY2021 (BY) ($ M)             float64
# DME PY Agency Funding ($ M)                     float64
# DME PY Contributions ($ M)                      float64
# DME CY Agency Funding ($ M)                     float64
# DME CY Contributions ($ M)                      float64
# DME BY Agency Funding ($ M)                     float64
# DME BY Contributions ($ M)                      float64
# DME BY Budget Authority Agency Funding ($ M)    float64
# O&M PY Agency Funding ($ M)                     float64
# O&M PY Contributions ($ M)                      float64
# ...

# %% [markdown]
# # Join Tables

# %%
it_dashboard = portfolio.join(business_case, on='Unique_Investment_Identifier', how='left').reset_index()
it_dashboard.index.rename("Investment_Id", inplace=True)

# %% [markdown]
# # IT Dashboard Final Table

# %%
it_dashboard.isna().sum()
# Out:
# Unique_Investment_Identifier                     0
# IT_Portfolio                                     0
# Investment_Type                                  0
# Investment_Name                                  0
# Description                                      0
# primary_service_area                             0
# Total IT Spending FY2019 (PY) ($ M)              0
# Total IT Spending FY2020 (CY) ($ M)              0
# Total IT Spending FY2021 (BY) ($ M)              0
# DME PY Agency Funding ($ M)                      0
# DME PY Contributions ($ M)                       0
# DME CY Agency Funding ($ M)                      0
# DME CY Contributions ($ M)                       0
# DME BY Agency Funding ($ M)                      0
# DME BY Contributions ($ M)                       0
# DME BY Budget Authority Agency Funding ($ M)     0
# O&M PY Agency Funding ($ M)                      0
# O&M PY Contributions ($ M)                       0
# ...

# %%
len(it_dashboard)
# Out:
# 109

# %% [markdown]
# All the business case investments (consisting of only major investments) joined with IT Porfolio table. We're missing PM Name, Start/End Years, and comments for non-major investments.
#
# In total, we're still missing:
# - Active
# - Comments
# - Investment_End/Start_Year
# - Investment_Manager_Name

# %%
it_dashboard.head()
# Out:
#               Unique_Investment_Identifier  \
# Investment_Id
# 0                            023-999993200
# 1                            023-999990060
# 2                            023-999990080
# 3                            023-999991100
# 4                            023-999993100
#
#                                                    IT_Portfolio  \
# Investment_Id
# 0              02 - Administrative Services and Support Systems
# 1              02 - Administrative Services and Support Systems
# 2                                         01 - Mission Delivery
# 3              02 - Administrative Services and Support Systems
# 4              02 - Administrative Services and Support Systems
#
#                      Investment_Type                      Investment_Name  \
# Investment_Id
# 0              04 - Funding Transfer  Budget Formulation Line of Business
# 1              04 - Funding Transfer           eRulemaking (Contribution)
# ...

# %%
it_dashboard.to_csv("business_case_it_portfolio_joined.csv", na_rep='NULL')
